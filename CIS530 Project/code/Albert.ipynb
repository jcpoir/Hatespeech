# %% [markdown]
# # Setup
# Click the file icon on the left, then the upload file icon in the panel. Upload `implicit_hate_train.csv`, `implicit_hate_dev.csv`, and `implicit_hate_test.csv`

# %% [markdown]
# # Data loading

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np

# %%
folder = '/content/drive/MyDrive/CIS530/CIS530Project/'

# %%
major_class_train_data = pd.read_csv(folder+"implicit_hate_train.csv")
major_class_dev_data = pd.read_csv(folder+"implicit_hate_dev.csv")
major_class_test_data = pd.read_csv(folder+"implicit_hate_test.csv")
print("major_class relevant keys: `post`, `class`")
print("  post: the tweet (str)")
print("  class: takes the values `explicit_hate`, `implicit_hate`, or `not_hate` (str)")
# Out:
# major_class relevant keys: `post`, `class`
#   post: the tweet (str)
#   class: takes the values `explicit_hate`, `implicit_hate`, or `not_hate` (str)

# %%
minor_class_train_data = major_class_train_data[major_class_train_data['implicit_class'].notnull()].reset_index(drop=True)
minor_class_dev_data = major_class_dev_data[major_class_dev_data['implicit_class'].notnull()].reset_index(drop=True)
minor_class_test_data = major_class_test_data[major_class_test_data['implicit_class'].notnull()].reset_index(drop=True)

print("minor_class relevant keys: `post`, `implicit_class`")
print("post: the tweet (str)")
print("implicit_class: takes the values `incitement`, `inferiority`, `irony`, `stereotypical`, `threatening`, or `white_grievance` (str)")
# Out:
# minor_class relevant keys: `post`, `implicit_class`
# post: the tweet (str)
# implicit_class: takes the values `incitement`, `inferiority`, `irony`, `stereotypical`, `threatening`, or `white_grievance` (str)

# %%
major_class_train_data['implicit_class']
# Out:
# 0        stereotypical
# 1        stereotypical
# 2        stereotypical
# 3        stereotypical
# 4        stereotypical
#              ...
# 16431              NaN
# 16432              NaN
# 16433              NaN
# 16434              NaN
# 16435              NaN
# Name: implicit_class, Length: 16436, dtype: object

# %%
major_class_train_data.head()
# Out:
#    Unnamed: 0                                               post  \
# 0        8146  they do and you can check them the white on wh...
# 1       11071    " hes a very good boy " " mt : seriously  wt...
# 2       18416   rt :  " breadth of the benefits the family wa...
# 3         148   rt : how #jews feel about #whitepeople -  " t...
# 4       11302  at least 60 white south africans were murder b...
#
#            class implicit_class
# 0  implicit_hate  stereotypical
# 1  implicit_hate  stereotypical
# 2  implicit_hate  stereotypical
# 3  implicit_hate  stereotypical
# 4  implicit_hate  stereotypical

# %%
print(major_class_train_data.shape)
print(major_class_dev_data.shape)
print(major_class_test_data.shape)
# Out:
# (16436, 4)
# (2055, 4)
# (2989, 5)

# %%
minor_class_train_data.head()
# Out:
#    Unnamed: 0                                               post  \
# 0        8146  they do and you can check them the white on wh...
# 1       11071    " hes a very good boy " " mt : seriously  wt...
# 2       18416   rt :  " breadth of the benefits the family wa...
# 3         148   rt : how #jews feel about #whitepeople -  " t...
# 4       11302  at least 60 white south africans were murder b...
#
#            class implicit_class
# 0  implicit_hate  stereotypical
# 1  implicit_hate  stereotypical
# 2  implicit_hate  stereotypical
# 3  implicit_hate  stereotypical
# 4  implicit_hate  stereotypical

# %%
print(minor_class_train_data.shape)
print(minor_class_dev_data.shape)
print(minor_class_test_data.shape)
# Out:
# (4937, 4)
# (618, 4)
# (698, 5)

# %%
from sklearn.metrics import f1_score
def evaluation(prediction, label):
    f1 = f1_score(label, prediction, average='macro')
    print(f1)

# %% [markdown]
# # Albert Classifier
# https://github.com/NadirEM/nlp-notebooks/blob/master/Fine_tune_ALBERT_sentence_pair_classification.ipynb

# %%
# !pip install sentencepiece
# !pip install transformers==3.1.0
# !pip install simpletransformers==0.48.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 32.8 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==3.1.0
#   Downloading transformers-3.1.0-py3-none-any.whl (884 kB)
#      |████████████████████████████████| 884 kB 17.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==3.1.0) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==3.1.0) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==3.1.0) (2022.6.2)
# Collecting tokenizers==0.8.1.rc2
#   Downloading tokenizers-0.8.1rc2-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 46.0 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 54.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from transformers==3.1.0) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==3.1.0) (3.8.0)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.8/dist-packages (from transformers==3.1.0) (0.1.97)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from transformers==3.1.0) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->transformers==3.1.0) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.1.0) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.1.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.1.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==3.1.0) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==3.1.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==3.1.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==3.1.0) (1.2.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=83b4116ef3f24a7cb4928ad3a4769bd3023465ae173b035ff739aeee497919c3
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.53 tokenizers-0.8.1rc2 transformers-3.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpletransformers==0.48.1
#   Downloading simpletransformers-0.48.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 21.7 MB/s
# Collecting streamlit
#   Downloading streamlit-1.15.2-py2.py3-none-any.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 56.9 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Collecting tensorboardx
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 65.9 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (1.0.2)
# Collecting wandb
#   Downloading wandb-0.13.6-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 59.5 MB/s
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (4.64.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (0.8.1rc2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (1.21.6)
# Requirement already satisfied: transformers>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from simpletransformers==0.48.1) (1.7.3)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.2->simpletransformers==0.48.1) (0.1.97)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.2->simpletransformers==0.48.1) (3.8.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.2->simpletransformers==0.48.1) (0.0.53)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from transformers>=3.0.2->simpletransformers==0.48.1) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->transformers>=3.0.2->simpletransformers==0.48.1) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->simpletransformers==0.48.1) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->simpletransformers==0.48.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->simpletransformers==0.48.1) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers==0.48.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers==0.48.1) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers==0.48.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers==0.48.1) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers>=3.0.2->simpletransformers==0.48.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers>=3.0.2->simpletransformers==0.48.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->simpletransformers==0.48.1) (3.1.0)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (9.0.0)
# Collecting rich>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 56.8 MB/s
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (4.13.0)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (4.2.0)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 68.6 MB/s
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (1.5.1)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Collecting watchdog
#   Downloading watchdog-2.2.0-py3-none-manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 8.4 MB/s
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 73.6 MB/s
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (5.2.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (3.19.6)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (4.4.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (6.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers==0.48.1) (7.1.2)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 63.2 MB/s
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers==0.48.1) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers==0.48.1) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers==0.48.1) (4.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers==0.48.1) (2.11.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers==0.48.1) (3.11.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers==0.48.1) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers==0.48.1) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers==0.48.1) (5.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers==0.48.1) (2.0.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit->simpletransformers==0.48.1) (2.6.1)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 8.9 MB/s
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators>=0.2->streamlit->simpletransformers==0.48.1) (4.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb->simpletransformers==0.48.1) (57.4.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.8/dist-packages (from wandb->simpletransformers==0.48.1) (2.3)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 57.7 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb->simpletransformers==0.48.1) (6.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb->simpletransformers==0.48.1) (5.4.8)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.0-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 70.5 MB/s
#   Downloading sentry_sdk-1.10.1-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 76.3 MB/s
#   Downloading sentry_sdk-1.10.0-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 75.2 MB/s
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 59.2 MB/s
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 73.1 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 64.2 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 53.0 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 6.1 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 69.8 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 70.7 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 75.6 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 78.8 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 71.4 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 77.2 MB/s
# Building wheels for collected packages: seqeval, validators, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16179 sha256=97fdc9b801ea28ed53e8c6767115c0ee33ad11cafcc79fbc262191e960d66923
#   Stored in directory: /root/.cache/pip/wheels/ad/5c/ba/05fa33fa5855777b7d686e843ec07452f22a66a138e290e732
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=d827305604428340feb631e99282a0fa990d2dee1dbc0f857ef10ff03bca381b
#   Stored in directory: /root/.cache/pip/wheels/19/09/72/3eb74d236bb48bd0f3c6c3c83e4e0c5bbfcbcad7c6c3539db8
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=fe22f40b93cbb32d06c36256a0f600b3dff7f4a37ccd636e45442f140d0807cf
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built seqeval validators pathtools
# Installing collected packages: smmap, gitdb, commonmark, watchdog, validators, shortuuid, setproctitle, sentry-sdk, semver, rich, pympler, pydeck, pathtools, gitpython, docker-pycreds, blinker, wandb, tensorboardx, streamlit, seqeval, simpletransformers
# Successfully installed blinker-1.5 commonmark-0.9.1 docker-pycreds-0.4.0 gitdb-4.0.10 gitpython-3.1.29 pathtools-0.1.2 pydeck-0.8.0 pympler-1.0.1 rich-12.6.0 semver-2.13.0 sentry-sdk-1.9.0 seqeval-1.2.2 setproctitle-1.3.2 shortuuid-1.0.11 simpletransformers-0.48.1 smmap-5.0.0 streamlit-1.15.2 tensorboardx-2.5.1 validators-0.20.0 wandb-0.13.6 watchdog-2.2.0

# %%
major_label_2_idx = {'not_hate' : 0, 'implicit_hate': 1, 'explicit_hate' : 2}
major_idx_2_label = {0: 'not_hate', 1:'implicit_hate',2:'explicit_hate'}
vector_major2idx = np.vectorize(lambda x: major_label_2_idx[x])

# %%
major_class_test_data.dropna(subset=['class'], inplace=True)

# %%
major_class_test_data
# Out:
#       Unnamed: 0                                               post  class  \
# 0          21358  One of my good friends from high school is bla...      1
# 1          10769  religion of peace wants to kill all the jews  ...      1
# 2          11846  we also have these people speaking out on the ...      1
# 3          16656  . 6219  408 ? 5895  116 ? what's the actual fi...      1
# 4          16195  no amnesty ! ! many will be able to apply for ...      1
# ...          ...                                                ...    ...
# 2053       12111  1850 white vs slave ... white live longer ... ...      0
# 2054        4180       is a open white nationalists website sir ...      0
# 2055       14950  another way wall street big business democrats...      0
# 2056        9474  because bannon thinks u r only american if u r...      0
# 2057       12209  average black in america is 20 % european and ...      0
#
#      implicit_class class_x
# 0     stereotypical     NaN
# 1     stereotypical     NaN
# 2     stereotypical     NaN
# 3     stereotypical     NaN
# 4     stereotypical     NaN
# ...             ...     ...
# 2053            NaN     NaN
# 2054            NaN     NaN
# 2055            NaN     NaN
# 2056            NaN     NaN
# 2057            NaN     NaN
#
# [2058 rows x 5 columns]

# %%
major_class_train_data['class'] = vector_major2idx(major_class_train_data['class'])
major_class_dev_data['class'] = vector_major2idx(major_class_dev_data['class'])
major_class_test_data['class'] = vector_major2idx(major_class_test_data['class'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-1f7b711464f8> in <module>
# ----> 1 major_class_train_data['class'] = vector_major2idx(major_class_train_data['class'])
#       2 major_class_dev_data['class'] = vector_major2idx(major_class_dev_data['class'])
#       3 major_class_test_data['class'] = vector_major2idx(major_class_test_data['class'])
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# -> 2163         return self._vectorize_call(func=func, args=vargs)
#    2164
#    2165     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2239             res = func()
#    2240         else:
# -> 2241             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2242
#    2243             # Convert args to object arrays first
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2199
#    2200             inputs = [arg.flat[0] for arg in args]
# -> 2201             outputs = func(*inputs)
#    2202
#    2203             # Performance note: profiling indicates that -- for simple
#
# <ipython-input-63-e648b7576841> in <lambda>(x)
#       1 major_label_2_idx = {'not_hate' : 0, 'implicit_hate': 1, 'explicit_hate' : 2}
#       2 major_idx_2_label = {0: 'not_hate', 1:'implicit_hate',2:'explicit_hate'}
# ----> 3 vector_major2idx = np.vectorize(lambda x: major_label_2_idx[x])
#
# KeyError: 1

# %%
major_class_test_data['class'] = vector_major2idx(major_class_test_data['class'])

# %%
minor_class_train_data = major_class_train_data[major_class_train_data['implicit_class'].notnull()].reset_index(drop=True)
minor_class_dev_data = major_class_dev_data[major_class_dev_data['implicit_class'].notnull()].reset_index(drop=True)
minor_class_test_data = major_class_test_data[major_class_test_data['implicit_class'].notnull()].reset_index(drop=True)

# %%
from simpletransformers.classification import ClassificationModel
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()

# load the dataset
data = major_class_train_data
data = data.iloc[:,1:3]
data["class"] = labelencoder.fit_transform(data["class"])

total_classes  = len(labelencoder.classes_)

# Create a ClassificationModel
model = ClassificationModel(
    'albert',
    'albert-base-v2',
    num_labels=total_classes,
    use_cuda=True,
    args={'learning_rate':1e-5,'save_model_every_epoch': False,'num_train_epochs': 2, 'reprocess_input_data': True, 'overwrite_output_dir': True}
) 

# Train the model
model.train_model(data,output_dir=None)
# Out:
# Some weights of the model checkpoint at albert-base-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.bias', 'predictions.LayerNorm.weight', 'predictions.LayerNorm.bias', 'predictions.dense.weight', 'predictions.dense.bias', 'predictions.decoder.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.8/dist-packages/simpletransformers/classification/classification_model.py:303: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#   0%|          | 0/16436 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 0 of 2:   0%|          | 0/2055 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:257: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Running Epoch 1 of 2:   0%|          | 0/2055 [00:00<?, ?it/s]

# %%
# load the dataset
test_major = major_class_test_data.iloc[:,1:2]
prediction = model.predict(test_major.post)
# Out:
#   0%|          | 0/2058 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]

# %%
from sklearn.metrics import f1_score
print('accuracy on dev set:',f1_score(major_class_test_data['class'], prediction[0], average='macro'))
# Out:
# accuracy on dev set: 0.23708723208178065

# %%
labelencoder = LabelEncoder()

# load the dataset
data = minor_class_train_data
data = data[['post','implicit_class']]
data["implicit_class"] = labelencoder.fit_transform(data["implicit_class"])

total_classes  = len(labelencoder.classes_)

# Create a ClassificationModel
model = ClassificationModel(
    'albert',
    'albert-base-v2',
    num_labels=total_classes,
    use_cuda=True,
    args={'learning_rate':1e-5,'save_model_every_epoch': False,'num_train_epochs': 2, 'reprocess_input_data': True, 'overwrite_output_dir': True}
) 

# Train the model
model.train_model(data,output_dir=None)
# Out:
# <ipython-input-94-7c29c9c45fb1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["implicit_class"] = labelencoder.fit_transform(data["implicit_class"])
# Some weights of the model checkpoint at albert-base-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.bias', 'predictions.LayerNorm.weight', 'predictions.LayerNorm.bias', 'predictions.dense.weight', 'predictions.dense.bias', 'predictions.decoder.weight', 'predictions.decoder.bias']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.8/dist-packages/simpletransformers/classification/classification_model.py:303: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#   0%|          | 0/4937 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Running Epoch 0 of 2:   0%|          | 0/618 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:257: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# Running Epoch 1 of 2:   0%|          | 0/618 [00:00<?, ?it/s]

# %%
# load the dataset
test_minor = minor_class_test_data[['post','implicit_class']]
prediction = model.predict(test_minor.post)
# Out:
#   0%|          | 0/698 [00:00<?, ?it/s]
#   0%|          | 0/88 [00:00<?, ?it/s]

# %%
minor_class_test_data["implicit_class"] = labelencoder.fit_transform(minor_class_test_data["implicit_class"])

# %%
print('accuracy on dev set:',f1_score(minor_class_test_data['implicit_class'], prediction[0], average='macro'))
# Out:
# accuracy on dev set: 0.2352346580672434

# %% [markdown]
# # BertForSequenceClassification
# https://huggingface.co/docs/transformers/v4.25.1/en/model_doc/bert#transformers.BertForSequenceClassification
